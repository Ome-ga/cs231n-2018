# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.373695
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** -The loss function is -1 * log[1 / cumprod (cumsum exp (scores[i, j] -  scores[i, y[i])) from i = 0 to i = num_classes - 1
# , due to num_classes equals 10 and exp(scores[i, j] -  scores[i, y[i]) tends to 0.

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -1.831290 analytic: -1.831290, relative error: 2.875186e-08
# numerical: 0.866548 analytic: 0.866548, relative error: 2.299091e-08
# numerical: -0.531229 analytic: -0.531229, relative error: 3.141951e-08
# numerical: 1.803525 analytic: 1.803525, relative error: 1.613227e-09
# numerical: 1.526008 analytic: 1.526008, relative error: 2.950825e-08
# numerical: -0.085249 analytic: -0.085249, relative error: 5.137405e-08
# numerical: -3.321552 analytic: -3.321552, relative error: 2.562204e-08
# numerical: 1.279640 analytic: 1.279640, relative error: 4.952276e-08
# numerical: -2.274657 analytic: -2.274657, relative error: 2.021995e-08
# numerical: 4.697702 analytic: 4.697702, relative error: 1.047564e-08
# numerical: -1.149069 analytic: -1.149070, relative error: 7.151402e-08
# numerical: -1.191536 analytic: -1.191536, relative error: 2.994126e-08
# numerical: -1.297439 analytic: -1.297439, relative error: 4.930046e-09
# numerical: 0.090463 analytic: 0.090463, relative error: 9.921716e-07
# numerical: -0.329826 analytic: -0.329826, relative error: 5.911056e-08
# numerical: 0.833758 analytic: 0.833758, relative error: 8.688662e-08
# numerical: 3.305315 analytic: 3.305315, relative error: 1.860004e-08
# numerical: -0.691272 analytic: -0.691272, relative error: 2.975885e-08
# numerical: -3.305426 analytic: -3.305426, relative error: 5.823455e-09
# numerical: 0.191874 analytic: 0.191874, relative error: 1.489807e-07

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.373695e+00 computed in 0.160127s
# vectorized loss: 2.373695e+00 computed in 0.021004s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7]
regularization_strengths = [2.5e4, 5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
num_lr_iterate = 5
num_reg_iterate = 5
step_lr = (learning_rates[1] - learning_rates[0]) / num_lr_iterate
step_reg = (regularization_strengths[1] - regularization_strengths[0]) / num_reg_iterate
for i in range(num_lr_iterate + 1):
    lr = learning_rates[0] + i * step_lr
    for j in range(num_reg_iterate):
        reg = regularization_strengths[0] +j * step_reg
        softmax = Softmax()
        softmax.train(X_train, y_train, learning_rate=lr, reg=reg, num_iters=1500, verbose=True)
        y_train_pred = softmax.predict(X_train)
        y_val_pred = softmax.predict(X_val)
        train_accuracy = np.mean(y_train == y_train_pred)
        val_accuracy = np.mean(y_val == y_val_pred)
        results[(lr, reg)] = (train_accuracy, val_accuracy)
        if (val_accuracy > best_val):
            best_val = val_accuracy
            best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 775.986902
# iteration 100 / 1500: loss 284.911799
# iteration 200 / 1500: loss 105.522847
# iteration 300 / 1500: loss 39.966796
# iteration 400 / 1500: loss 15.924582
# iteration 500 / 1500: loss 7.203729
# iteration 600 / 1500: loss 3.999995
# iteration 700 / 1500: loss 2.777570
# iteration 800 / 1500: loss 2.366352
# iteration 900 / 1500: loss 2.161574
# iteration 1000 / 1500: loss 2.175499
# iteration 1100 / 1500: loss 2.006882
# iteration 1200 / 1500: loss 2.075147
# iteration 1300 / 1500: loss 2.065187
# iteration 1400 / 1500: loss 2.014751
# iteration 0 / 1500: loss 910.927222
# iteration 100 / 1500: loss 273.625916
# iteration 200 / 1500: loss 83.334105
# iteration 300 / 1500: loss 26.455445
# iteration 400 / 1500: loss 9.428247
# iteration 500 / 1500: loss 4.299364
# iteration 600 / 1500: loss 2.722729
# iteration 700 / 1500: loss 2.275041
# iteration 800 / 1500: loss 2.128445
# iteration 900 / 1500: loss 2.108064
# iteration 1000 / 1500: loss 2.081729
# iteration 1100 / 1500: loss 2.146059
# iteration 1200 / 1500: loss 2.114234
# iteration 1300 / 1500: loss 2.094922
# iteration 1400 / 1500: loss 2.088485
# iteration 0 / 1500: loss 1080.583516
# iteration 100 / 1500: loss 265.510873
# iteration 200 / 1500: loss 66.478039
# iteration 300 / 1500: loss 17.935586
# iteration 400 / 1500: loss 5.960532
# iteration 500 / 1500: loss 3.026949
# iteration 600 / 1500: loss 2.343676
# iteration 700 / 1500: loss 2.219271
# iteration 800 / 1500: loss 2.122748
# iteration 900 / 1500: loss 2.136624
# iteration 1000 / 1500: loss 2.182029
# iteration 1100 / 1500: loss 2.095573
# iteration 1200 / 1500: loss 2.121875
# iteration 1300 / 1500: loss 2.135741
# iteration 1400 / 1500: loss 2.158808
# iteration 0 / 1500: loss 1231.789240
# iteration 100 / 1500: loss 247.858985
# iteration 200 / 1500: loss 51.320610
# iteration 300 / 1500: loss 11.988536
# iteration 400 / 1500: loss 4.092628
# iteration 500 / 1500: loss 2.518968
# iteration 600 / 1500: loss 2.207474
# iteration 700 / 1500: loss 2.172963
# iteration 800 / 1500: loss 2.109578
# iteration 900 / 1500: loss 2.120533
# iteration 1000 / 1500: loss 2.106325
# iteration 1100 / 1500: loss 2.125176
# iteration 1200 / 1500: loss 2.116555
# iteration 1300 / 1500: loss 2.099795
# iteration 1400 / 1500: loss 2.130756
# iteration 0 / 1500: loss 1386.521356
# iteration 100 / 1500: loss 228.230595
# iteration 200 / 1500: loss 39.086236
# iteration 300 / 1500: loss 8.158333
# iteration 400 / 1500: loss 3.088683
# iteration 500 / 1500: loss 2.310066
# iteration 600 / 1500: loss 2.135169
# iteration 700 / 1500: loss 2.133028
# iteration 800 / 1500: loss 2.160751
# iteration 900 / 1500: loss 2.061942
# iteration 1000 / 1500: loss 2.078929
# iteration 1100 / 1500: loss 2.142351
# iteration 1200 / 1500: loss 2.110130
# iteration 1300 / 1500: loss 2.179815
# iteration 1400 / 1500: loss 2.106595
# iteration 0 / 1500: loss 779.002301
# iteration 100 / 1500: loss 128.688012
# iteration 200 / 1500: loss 22.725500
# iteration 300 / 1500: loss 5.450261
# iteration 400 / 1500: loss 2.665555
# iteration 500 / 1500: loss 2.141372
# iteration 600 / 1500: loss 2.060245
# iteration 700 / 1500: loss 2.097895
# iteration 800 / 1500: loss 2.081025
# iteration 900 / 1500: loss 2.081331
# iteration 1000 / 1500: loss 2.071763
# iteration 1100 / 1500: loss 2.132217
# iteration 1200 / 1500: loss 2.069534
# iteration 1300 / 1500: loss 2.151207
# iteration 1400 / 1500: loss 2.112786
# iteration 0 / 1500: loss 924.294354
# iteration 100 / 1500: loss 106.656977
# iteration 200 / 1500: loss 13.994005
# iteration 300 / 1500: loss 3.506213
# iteration 400 / 1500: loss 2.273519
# iteration 500 / 1500: loss 2.117363
# iteration 600 / 1500: loss 2.091747
# iteration 700 / 1500: loss 2.099317
# iteration 800 / 1500: loss 2.078164
# iteration 900 / 1500: loss 2.026757
# iteration 1000 / 1500: loss 2.095623
# iteration 1100 / 1500: loss 2.101024
# iteration 1200 / 1500: loss 2.085146
# iteration 1300 / 1500: loss 2.121528
# iteration 1400 / 1500: loss 2.105730
# iteration 0 / 1500: loss 1089.396012
# iteration 100 / 1500: loss 87.719211
# iteration 200 / 1500: loss 8.908471
# iteration 300 / 1500: loss 2.620603
# iteration 400 / 1500: loss 2.136997
# iteration 500 / 1500: loss 2.132867
# iteration 600 / 1500: loss 2.120768
# iteration 700 / 1500: loss 2.060856
# iteration 800 / 1500: loss 2.098362
# iteration 900 / 1500: loss 2.142303
# iteration 1000 / 1500: loss 2.156844
# iteration 1100 / 1500: loss 2.170275
# iteration 1200 / 1500: loss 2.091147
# iteration 1300 / 1500: loss 2.117933
# iteration 1400 / 1500: loss 2.150322
# iteration 0 / 1500: loss 1213.725623
# iteration 100 / 1500: loss 68.367809
# iteration 200 / 1500: loss 5.732974
# iteration 300 / 1500: loss 2.334665
# iteration 400 / 1500: loss 2.161495
# iteration 500 / 1500: loss 2.127560
# iteration 600 / 1500: loss 2.129363
# iteration 700 / 1500: loss 2.114652
# iteration 800 / 1500: loss 2.094839
# iteration 900 / 1500: loss 2.174745
# iteration 1000 / 1500: loss 2.139641
# iteration 1100 / 1500: loss 2.107978
# iteration 1200 / 1500: loss 2.074026
# iteration 1300 / 1500: loss 2.161554
# iteration 1400 / 1500: loss 2.105945
# iteration 0 / 1500: loss 1398.590025
# iteration 100 / 1500: loss 55.073137
# iteration 200 / 1500: loss 4.131160
# iteration 300 / 1500: loss 2.224953
# iteration 400 / 1500: loss 2.096349
# iteration 500 / 1500: loss 2.180567
# iteration 600 / 1500: loss 2.143274
# iteration 700 / 1500: loss 2.090183
# iteration 800 / 1500: loss 2.126830
# iteration 900 / 1500: loss 2.153006
# iteration 1000 / 1500: loss 2.142510
# iteration 1100 / 1500: loss 2.127636
# iteration 1200 / 1500: loss 2.171853
# iteration 1300 / 1500: loss 2.125458
# iteration 1400 / 1500: loss 2.163557
# iteration 0 / 1500: loss 777.295906
# iteration 100 / 1500: loss 58.145178
# iteration 200 / 1500: loss 6.179533
# iteration 300 / 1500: loss 2.370990
# iteration 400 / 1500: loss 2.112638
# iteration 500 / 1500: loss 2.088724
# iteration 600 / 1500: loss 2.068819
# iteration 700 / 1500: loss 2.128630
# iteration 800 / 1500: loss 2.099403
# iteration 900 / 1500: loss 2.067377
# iteration 1000 / 1500: loss 2.072059
# iteration 1100 / 1500: loss 2.067182
# iteration 1200 / 1500: loss 2.113064
# iteration 1300 / 1500: loss 2.069162
# iteration 1400 / 1500: loss 2.104391
# iteration 0 / 1500: loss 937.422844
# iteration 100 / 1500: loss 42.079807
# iteration 200 / 1500: loss 3.801019
# iteration 300 / 1500: loss 2.187705
# iteration 400 / 1500: loss 2.087201
# iteration 500 / 1500: loss 2.123776
# iteration 600 / 1500: loss 2.099326
# iteration 700 / 1500: loss 2.044844
# iteration 800 / 1500: loss 2.126802
# iteration 900 / 1500: loss 2.077109
# iteration 1000 / 1500: loss 2.113518
# iteration 1100 / 1500: loss 2.081965
# iteration 1200 / 1500: loss 2.082572
# iteration 1300 / 1500: loss 2.096082
# iteration 1400 / 1500: loss 2.143641
# iteration 0 / 1500: loss 1081.892688
# iteration 100 / 1500: loss 29.269670
# iteration 200 / 1500: loss 2.828425
# iteration 300 / 1500: loss 2.125646
# iteration 400 / 1500: loss 2.119213
# iteration 500 / 1500: loss 2.142550
# iteration 600 / 1500: loss 2.120499
# iteration 700 / 1500: loss 2.064752
# iteration 800 / 1500: loss 2.099336
# iteration 900 / 1500: loss 2.083162
# iteration 1000 / 1500: loss 2.085721
# iteration 1100 / 1500: loss 2.122766
# iteration 1200 / 1500: loss 2.092079
# iteration 1300 / 1500: loss 2.133891
# iteration 1400 / 1500: loss 2.192656
# iteration 0 / 1500: loss 1246.066182
# iteration 100 / 1500: loss 20.531899
# iteration 200 / 1500: loss 2.391045
# iteration 300 / 1500: loss 2.116800
# iteration 400 / 1500: loss 2.127527
# iteration 500 / 1500: loss 2.113804
# iteration 600 / 1500: loss 2.147530
# iteration 700 / 1500: loss 2.160698
# iteration 800 / 1500: loss 2.132422
# iteration 900 / 1500: loss 2.077053
# iteration 1000 / 1500: loss 2.110193
# iteration 1100 / 1500: loss 2.130268
# iteration 1200 / 1500: loss 2.068905
# iteration 1300 / 1500: loss 2.153608
# iteration 1400 / 1500: loss 2.090379
# iteration 0 / 1500: loss 1375.642334
# iteration 100 / 1500: loss 14.129027
# iteration 200 / 1500: loss 2.215243
# iteration 300 / 1500: loss 2.126204
# iteration 400 / 1500: loss 2.151090
# iteration 500 / 1500: loss 2.123635
# iteration 600 / 1500: loss 2.087206
# iteration 700 / 1500: loss 2.162910
# iteration 800 / 1500: loss 2.168664
# iteration 900 / 1500: loss 2.115574
# iteration 1000 / 1500: loss 2.101740
# iteration 1100 / 1500: loss 2.141926
# iteration 1200 / 1500: loss 2.149319
# iteration 1300 / 1500: loss 2.090652
# iteration 1400 / 1500: loss 2.118156
# iteration 0 / 1500: loss 769.059257
# iteration 100 / 1500: loss 26.681667
# iteration 200 / 1500: loss 2.846898
# iteration 300 / 1500: loss 2.136137
# iteration 400 / 1500: loss 2.093661
# iteration 500 / 1500: loss 2.040860
# iteration 600 / 1500: loss 2.067501
# iteration 700 / 1500: loss 2.021494
# iteration 800 / 1500: loss 2.071581
# iteration 900 / 1500: loss 2.051254
# iteration 1000 / 1500: loss 2.162044
# iteration 1100 / 1500: loss 2.051619
# iteration 1200 / 1500: loss 2.039597
# iteration 1300 / 1500: loss 2.017896
# iteration 1400 / 1500: loss 2.104502
# iteration 0 / 1500: loss 943.228703
# iteration 100 / 1500: loss 17.227270
# iteration 200 / 1500: loss 2.337035
# iteration 300 / 1500: loss 2.148394
# iteration 400 / 1500: loss 2.091592
# iteration 500 / 1500: loss 2.144687
# iteration 600 / 1500: loss 2.159369
# iteration 700 / 1500: loss 2.091707
# iteration 800 / 1500: loss 2.111241
# iteration 900 / 1500: loss 2.186745
# iteration 1000 / 1500: loss 2.100571
# iteration 1100 / 1500: loss 2.069287
# iteration 1200 / 1500: loss 2.189074
# iteration 1300 / 1500: loss 2.117484
# iteration 1400 / 1500: loss 2.088615
# iteration 0 / 1500: loss 1081.797789
# iteration 100 / 1500: loss 10.784712
# iteration 200 / 1500: loss 2.173642
# iteration 300 / 1500: loss 2.106751
# iteration 400 / 1500: loss 2.171216
# iteration 500 / 1500: loss 2.067362
# iteration 600 / 1500: loss 2.137940
# iteration 700 / 1500: loss 2.047333
# iteration 800 / 1500: loss 2.159323
# iteration 900 / 1500: loss 2.097507
# iteration 1000 / 1500: loss 2.152767
# iteration 1100 / 1500: loss 2.155231
# iteration 1200 / 1500: loss 2.117275
# iteration 1300 / 1500: loss 2.107759
# iteration 1400 / 1500: loss 2.135465
# iteration 0 / 1500: loss 1241.719143
# iteration 100 / 1500: loss 7.125565
# iteration 200 / 1500: loss 2.158266
# iteration 300 / 1500: loss 2.115952
# iteration 400 / 1500: loss 2.128849
# iteration 500 / 1500: loss 2.170627
# iteration 600 / 1500: loss 2.133865
# iteration 700 / 1500: loss 2.121629
# iteration 800 / 1500: loss 2.131560
# iteration 900 / 1500: loss 2.117449
# iteration 1000 / 1500: loss 2.130347
# iteration 1100 / 1500: loss 2.158143
# iteration 1200 / 1500: loss 2.098741
# iteration 1300 / 1500: loss 2.078592
# iteration 1400 / 1500: loss 2.082157
# iteration 0 / 1500: loss 1367.948652
# iteration 100 / 1500: loss 4.828065
# iteration 200 / 1500: loss 2.154913
# iteration 300 / 1500: loss 2.130830
# iteration 400 / 1500: loss 2.112098
# iteration 500 / 1500: loss 2.169908
# iteration 600 / 1500: loss 2.113325
# iteration 700 / 1500: loss 2.136234
# iteration 800 / 1500: loss 2.167284
# iteration 900 / 1500: loss 2.120094
# iteration 1000 / 1500: loss 2.145071
# iteration 1100 / 1500: loss 2.145247
# iteration 1200 / 1500: loss 2.127543
# iteration 1300 / 1500: loss 2.112460
# iteration 1400 / 1500: loss 2.130354
# iteration 0 / 1500: loss 777.955777
# iteration 100 / 1500: loss 13.063891
# iteration 200 / 1500: loss 2.249301
# iteration 300 / 1500: loss 2.105826
# iteration 400 / 1500: loss 2.081350
# iteration 500 / 1500: loss 2.134438
# iteration 600 / 1500: loss 2.061586
# iteration 700 / 1500: loss 2.057136
# iteration 800 / 1500: loss 2.102571
# iteration 900 / 1500: loss 2.105658
# iteration 1000 / 1500: loss 2.064063
# iteration 1100 / 1500: loss 2.085871
# iteration 1200 / 1500: loss 2.127960
# iteration 1300 / 1500: loss 2.109634
# iteration 1400 / 1500: loss 2.123573
# iteration 0 / 1500: loss 934.773864
# iteration 100 / 1500: loss 7.672005
# iteration 200 / 1500: loss 2.115560
# iteration 300 / 1500: loss 2.084371
# iteration 400 / 1500: loss 2.105423
# iteration 500 / 1500: loss 2.062240
# iteration 600 / 1500: loss 2.124057
# iteration 700 / 1500: loss 2.095616
# iteration 800 / 1500: loss 2.094227
# iteration 900 / 1500: loss 2.115734
# iteration 1000 / 1500: loss 2.110636
# iteration 1100 / 1500: loss 2.047646
# iteration 1200 / 1500: loss 2.043137
# iteration 1300 / 1500: loss 2.112386
# iteration 1400 / 1500: loss 2.140027
# iteration 0 / 1500: loss 1099.400790
# iteration 100 / 1500: loss 4.895301
# iteration 200 / 1500: loss 2.109596
# iteration 300 / 1500: loss 2.111249
# iteration 400 / 1500: loss 2.122201
# iteration 500 / 1500: loss 2.136939
# iteration 600 / 1500: loss 2.130986
# iteration 700 / 1500: loss 2.100580
# iteration 800 / 1500: loss 2.036338
# iteration 900 / 1500: loss 2.060973
# iteration 1000 / 1500: loss 2.104624
# iteration 1100 / 1500: loss 2.119338
# iteration 1200 / 1500: loss 2.170670
# iteration 1300 / 1500: loss 2.095602
# iteration 1400 / 1500: loss 2.091377
# iteration 0 / 1500: loss 1239.497572
# iteration 100 / 1500: loss 3.478402
# iteration 200 / 1500: loss 2.157732
# iteration 300 / 1500: loss 2.135112
# iteration 400 / 1500: loss 2.126339
# iteration 500 / 1500: loss 2.107586
# iteration 600 / 1500: loss 2.150361
# iteration 700 / 1500: loss 2.072577
# iteration 800 / 1500: loss 2.108309
# iteration 900 / 1500: loss 2.094013
# iteration 1000 / 1500: loss 2.201084
# iteration 1100 / 1500: loss 2.051051
# iteration 1200 / 1500: loss 2.100657
# iteration 1300 / 1500: loss 2.090098
# iteration 1400 / 1500: loss 2.088369
# iteration 0 / 1500: loss 1406.447817
# iteration 100 / 1500: loss 2.771208
# iteration 200 / 1500: loss 2.131524
# iteration 300 / 1500: loss 2.153431
# iteration 400 / 1500: loss 2.073638
# iteration 500 / 1500: loss 2.168808
# iteration 600 / 1500: loss 2.160458
# iteration 700 / 1500: loss 2.076255
# iteration 800 / 1500: loss 2.095425
# iteration 900 / 1500: loss 2.104018
# iteration 1000 / 1500: loss 2.166428
# iteration 1100 / 1500: loss 2.095146
# iteration 1200 / 1500: loss 2.112202
# iteration 1300 / 1500: loss 2.148503
# iteration 1400 / 1500: loss 2.106477
# iteration 0 / 1500: loss 775.811740
# iteration 100 / 1500: loss 6.957553
# iteration 200 / 1500: loss 2.118182
# iteration 300 / 1500: loss 2.130091
# iteration 400 / 1500: loss 2.009651
# iteration 500 / 1500: loss 2.134019
# iteration 600 / 1500: loss 2.109320
# iteration 700 / 1500: loss 2.090736
# iteration 800 / 1500: loss 2.043429
# iteration 900 / 1500: loss 2.098168
# iteration 1000 / 1500: loss 2.063615
# iteration 1100 / 1500: loss 2.183362
# iteration 1200 / 1500: loss 2.076212
# iteration 1300 / 1500: loss 2.076682
# iteration 1400 / 1500: loss 2.088017
# iteration 0 / 1500: loss 936.727363
# iteration 100 / 1500: loss 4.208676
# iteration 200 / 1500: loss 2.155003
# iteration 300 / 1500: loss 2.035641
# iteration 400 / 1500: loss 2.170729
# iteration 500 / 1500: loss 2.145942
# iteration 600 / 1500: loss 2.108449
# iteration 700 / 1500: loss 2.077118
# iteration 800 / 1500: loss 2.063589
# iteration 900 / 1500: loss 2.110522
# iteration 1000 / 1500: loss 2.094535
# iteration 1100 / 1500: loss 2.147672
# iteration 1200 / 1500: loss 2.116779
# iteration 1300 / 1500: loss 2.111175
# iteration 1400 / 1500: loss 2.054835
# iteration 0 / 1500: loss 1090.645107
# iteration 100 / 1500: loss 2.972812
# iteration 200 / 1500: loss 2.072998
# iteration 300 / 1500: loss 2.151874
# iteration 400 / 1500: loss 2.103991
# iteration 500 / 1500: loss 2.126442
# iteration 600 / 1500: loss 2.123127
# iteration 700 / 1500: loss 2.108252
# iteration 800 / 1500: loss 2.122281
# iteration 900 / 1500: loss 2.138220
# iteration 1000 / 1500: loss 2.135361
# iteration 1100 / 1500: loss 2.090102
# iteration 1200 / 1500: loss 2.108869
# iteration 1300 / 1500: loss 2.072728
# iteration 1400 / 1500: loss 2.117897
# iteration 0 / 1500: loss 1224.300470
# iteration 100 / 1500: loss 2.448204
# iteration 200 / 1500: loss 2.140524
# iteration 300 / 1500: loss 2.132090
# iteration 400 / 1500: loss 2.093465
# iteration 500 / 1500: loss 2.101357
# iteration 600 / 1500: loss 2.139319
# iteration 700 / 1500: loss 2.075137
# iteration 800 / 1500: loss 2.159896
# iteration 900 / 1500: loss 2.121707
# iteration 1000 / 1500: loss 2.121338
# iteration 1100 / 1500: loss 2.165856
# iteration 1200 / 1500: loss 2.125209
# iteration 1300 / 1500: loss 2.130440
# iteration 1400 / 1500: loss 2.097292
# iteration 0 / 1500: loss 1379.165761
# iteration 100 / 1500: loss 2.348277
# iteration 200 / 1500: loss 2.170216
# iteration 300 / 1500: loss 2.063245
# iteration 400 / 1500: loss 2.132377
# iteration 500 / 1500: loss 2.153593
# iteration 600 / 1500: loss 2.163008
# iteration 700 / 1500: loss 2.176453
# iteration 800 / 1500: loss 2.177320
# iteration 900 / 1500: loss 2.132896
# iteration 1000 / 1500: loss 2.168856
# iteration 1100 / 1500: loss 2.106624
# iteration 1200 / 1500: loss 2.068125
# iteration 1300 / 1500: loss 2.149347
# iteration 1400 / 1500: loss 2.147829
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.328286 val accuracy: 0.341000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.322020 val accuracy: 0.334000
# lr 1.000000e-07 reg 3.500000e+04 train accuracy: 0.322143 val accuracy: 0.334000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.314837 val accuracy: 0.329000
# lr 1.000000e-07 reg 4.500000e+04 train accuracy: 0.311306 val accuracy: 0.320000
# lr 1.800000e-07 reg 2.500000e+04 train accuracy: 0.333408 val accuracy: 0.350000
# lr 1.800000e-07 reg 3.000000e+04 train accuracy: 0.318694 val accuracy: 0.333000
# lr 1.800000e-07 reg 3.500000e+04 train accuracy: 0.317551 val accuracy: 0.330000
# lr 1.800000e-07 reg 4.000000e+04 train accuracy: 0.308122 val accuracy: 0.328000
# lr 1.800000e-07 reg 4.500000e+04 train accuracy: 0.310571 val accuracy: 0.333000
# lr 2.600000e-07 reg 2.500000e+04 train accuracy: 0.330041 val accuracy: 0.345000
# lr 2.600000e-07 reg 3.000000e+04 train accuracy: 0.324163 val accuracy: 0.342000
# lr 2.600000e-07 reg 3.500000e+04 train accuracy: 0.319510 val accuracy: 0.335000
# lr 2.600000e-07 reg 4.000000e+04 train accuracy: 0.319061 val accuracy: 0.340000
# lr 2.600000e-07 reg 4.500000e+04 train accuracy: 0.307041 val accuracy: 0.317000
# lr 3.400000e-07 reg 2.500000e+04 train accuracy: 0.328429 val accuracy: 0.339000
# lr 3.400000e-07 reg 3.000000e+04 train accuracy: 0.323571 val accuracy: 0.334000
# lr 3.400000e-07 reg 3.500000e+04 train accuracy: 0.325898 val accuracy: 0.335000
# lr 3.400000e-07 reg 4.000000e+04 train accuracy: 0.314388 val accuracy: 0.334000
# lr 3.400000e-07 reg 4.500000e+04 train accuracy: 0.318327 val accuracy: 0.326000
# lr 4.200000e-07 reg 2.500000e+04 train accuracy: 0.327408 val accuracy: 0.336000
# lr 4.200000e-07 reg 3.000000e+04 train accuracy: 0.319265 val accuracy: 0.343000
# lr 4.200000e-07 reg 3.500000e+04 train accuracy: 0.322327 val accuracy: 0.340000
# lr 4.200000e-07 reg 4.000000e+04 train accuracy: 0.297469 val accuracy: 0.315000
# lr 4.200000e-07 reg 4.500000e+04 train accuracy: 0.306143 val accuracy: 0.314000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.324551 val accuracy: 0.336000
# lr 5.000000e-07 reg 3.000000e+04 train accuracy: 0.322041 val accuracy: 0.343000
# lr 5.000000e-07 reg 3.500000e+04 train accuracy: 0.318673 val accuracy: 0.336000
# lr 5.000000e-07 reg 4.000000e+04 train accuracy: 0.312102 val accuracy: 0.331000
# lr 5.000000e-07 reg 4.500000e+04 train accuracy: 0.313898 val accuracy: 0.315000
# best validation accuracy achieved during cross-validation: 0.350000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f4abb9fb2033> in <module>()
#       1 # evaluate on test set
#       2 # Evaluate the best softmax on test set
# ----> 3 y_test_pred = best_softmax.predict(X_test)
#       4 test_accuracy = np.mean(y_test == y_test_pred)
#       5 print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
#
# AttributeError: 'NoneType' object has no attribute 'predict'

# %% [markdown]
# **Inline Question** - *True or False*
#
# It's possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# *Your answer*:
#
# *Your explanation*:

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
